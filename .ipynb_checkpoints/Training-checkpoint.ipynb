# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pylab as plt
import sys
import random

from itertools import product

from Data_Loading import *
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer, StandardScaler
from sklearn.model_selection import GridSearchCV

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, make_scorer, r2_score
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import PolynomialFeatures
# Out:
# b

# %%
main_df = pd.read_csv('Banco de Dados/atributos/atributos_main.csv', index_col=0)
main_df['filepath'] = main_df['database']+'/'+main_df['filename']
main_df = main_df.set_index(['database', 'filename'])
main_df
# Out:
#                              v_eta_A5  v_eta_D5  v_eta_D4  v_eta_D3  v_eta_D2  \
# database  filename
# acm_mirum 10118334.clip.mp3  2.833333  2.200000  3.181818  2.354839  4.593750
#           10258351.clip.mp3  2.266667  3.200000  2.615385  3.227273  3.617284
#           10270809.clip.mp3  2.285714  2.266667  2.692308  2.147059  3.945946
#           10332517.clip.mp3  2.666667  2.666667  2.500000  2.920000  2.940000
#           10348303.clip.mp3  3.090909  2.266667  4.125000  3.041667  3.945946
# ...                               ...       ...       ...       ...       ...
# banco1    95.wav             3.750000  2.538462  3.000000  3.736842  3.918919
#           96.wav             2.833333  2.428571  2.571429  2.117647  4.264706
#           97.wav             2.428571  2.125000  2.428571  2.117647  4.235294
#           98.wav             3.000000  2.538462  2.916667  3.476190  4.424242
#           99.wav             3.500000  2.428571  2.916667  3.136364  3.106383
#
#                              v_eta_D1  v_sigma_A5  v_sigma_D5  v_sigma_D4  \
# database  filename
# acm_mirum 10118334.clip.mp3  9.187500    1.213352    0.400000    0.574960
#           10258351.clip.mp3  6.444444    0.442217    0.748331    0.624926
#           10270809.clip.mp3  7.891892    0.699854    0.442217    0.461538
#           10332517.clip.mp3  3.959459    0.471405    0.471405    0.731925
#           10348303.clip.mp3  5.192982    0.995859    0.442217    1.964529
# ...                               ...         ...         ...         ...
# banco1    95.wav             5.745098    0.433013    0.745797    0.852803
#           96.wav             8.500000    1.067187    0.494872    0.622700
#           97.wav             6.125000    0.728431    0.330719    0.728431
#           98.wav             8.314286    0.632456    1.082404    0.862007
#           99.wav             5.214286    0.500000    0.728431    0.953794
#
#                              v_sigma_D3  ...   v_sd_D2   v_sd_D1   v_sf_A5  \
# database  filename                       ...
# acm_mirum 10118334.clip.mp3    0.649982  ... -0.023721 -0.007043  0.721463
#           10258351.clip.mp3    0.419070  ... -0.040796 -0.040910  0.720558
#           10270809.clip.mp3    0.493031  ... -0.062429 -0.056861  0.716342
#           10332517.clip.mp3    0.271293  ... -0.058653 -0.053484  0.650508
#           10348303.clip.mp3    1.059841  ... -0.040350 -0.025611  0.573808
# ...                                 ...  ...       ...       ...       ...
# banco1    95.wav               0.440347  ... -0.054363 -0.037688  0.519931
#           96.wav               0.322190  ... -0.062304 -0.055434  0.683548
#           97.wav               0.322190  ... -0.032933 -0.038682  0.693360
#           98.wav               1.219643  ... -0.033274 -0.017450  0.705853
#           99.wav               0.919261  ... -0.072486 -0.047873  0.698925
#
#                               v_sf_D5   v_sf_D4   v_sf_D3   v_sf_D2   v_sf_D1  \
# database  filename
# acm_mirum 10118334.clip.mp3  0.690003  0.710161  0.501041  0.604924  0.308860
#           10258351.clip.mp3  0.762754  0.526791  0.331555  0.290153  0.160497
#           10270809.clip.mp3  0.614350  0.502162  0.446977  0.412124  0.292314
#           10332517.clip.mp3  0.615221  0.558058  0.446767  0.445115  0.247787
#           10348303.clip.mp3  0.692712  0.567320  0.689657  0.614103  0.408099
# ...                               ...       ...       ...       ...       ...
# banco1    95.wav             0.647449  0.496156  0.437015  0.530072  0.344177
#           96.wav             0.706678  0.632906  0.421532  0.384137  0.314319
#           97.wav             0.691660  0.717247  0.418132  0.331272  0.216553
#           98.wav             0.734266  0.565840  0.516848  0.410616  0.235306
#           99.wav             0.660706  0.656530  0.603633  0.558252  0.307923
#
#                                bpm                     filepath
# database  filename
# acm_mirum 10118334.clip.mp3   81.0  acm_mirum/10118334.clip.mp3
#           10258351.clip.mp3  234.5  acm_mirum/10258351.clip.mp3
#           10270809.clip.mp3   95.0  acm_mirum/10270809.clip.mp3
#           10332517.clip.mp3  129.0  acm_mirum/10332517.clip.mp3
#           10348303.clip.mp3   90.0  acm_mirum/10348303.clip.mp3
# ...                            ...                          ...
# banco1    95.wav             100.0                banco1/95.wav
#           96.wav              88.0                banco1/96.wav
#           97.wav              88.0                banco1/97.wav
#           98.wav             175.0                banco1/98.wav
#           99.wav             122.0                banco1/99.wav
#
# [6645 rows x 68 columns]

# %%
main_df['bpm'] = main_df['bpm'].apply(lambda bpm: round(bpm*2)/2)

X = main_df.loc[:, :'v_sd_D1']
y = main_df.loc[:, ['bpm']]
X_train, X_test, y_train, y_test = train_test_split(X, y)

y_train = y_train.values.reshape(-1,)
y_test = y_test.values.reshape(-1,)

plt.subplot(2,1,1)
plt.hist(y_train, bins = 273)
plt.subplot(2,1,2)
plt.hist(y_test, bins = 273)
plt.show()

# %%
normal_dict = {}

for bpm in main_df['bpm'].unique():
    normal_dict[bpm] = main_df[main_df['bpm'] == bpm]



random_df = main_df.sample(frac=1)
rnd_dict = {}

for bpm in random_df['bpm'].unique():
    rnd_dict[bpm] = random_df[random_df['bpm'] == bpm]

# %%
dicio = rnd_dict #Choose dictionary between random or not

train = pd.DataFrame()
cv = pd.DataFrame()
test = pd.DataFrame()

first = True

for lab, bpm_list in dicio.items():
    if(len(bpm_list)<10):
        train = pd.concat([train, bpm_list], axis=0)
    else:
        train_size = int(0.7*len(bpm_list))
        cv_size = int(0.15*len(bpm_list))
        test_size = int(0.15*len(bpm_list))
        
        train_set = bpm_list.iloc[:train_size]
        cv_set = bpm_list.iloc[train_size-1:train_size+cv_size]
        test_set = bpm_list.iloc[train_size+cv_size-1:]
        
        train = pd.concat([train, train_set], axis=0)
        cv = pd.concat([cv, cv_set], axis=0)
        test = pd.concat([test, test_set], axis=0)
        
        
X_train = train.loc[:, :'v_sd_D1']
y_train = train.loc[:, ['bpm']]

X_cv = cv.loc[:, :'v_sd_D1']
y_cv = cv.loc[:, ['bpm']]

X_test = test.loc[:, :'v_sd_D1']
y_test = test.loc[:, ['bpm']]


y_train = y_train.values.reshape(-1,)
y_cv = y_cv.values.reshape(-1,)
y_test = y_test.values.reshape(-1,)

plt.subplot(3,1,1)
plt.hist(y_train, bins = 273)
plt.subplot(3,1,2)
plt.hist(y_cv, bins = 273)
plt.subplot(3,1,3)
plt.hist(y_test, bins = 273)
plt.show()

# %%
X_train_std = StandardScaler().fit_transform(X_train)
X_cv_std = StandardScaler().fit_transform(X_cv)
X_test_std = StandardScaler().fit_transform(X_test)


results_df = pd.DataFrame({"Espaço":[],
                           "Train_loss_array":[], "Train_loss":[],
                           "CV_loss_array":[], "CV_loss":[],
                           "Test_loss_array":[], "Test_loss":[],
                           "num_iter":[], "time_elapsed":[]})



#alpha, 
alphas = [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3]
learning_rates = [0.001, 0.003, 0.01, 0.03, 0.1, 0.3]
layer_sizes = [(3,), (3,3), (5,), (5,5), (7,), (7,7), (9,), (9,9)]

max_iter = 4000

params_space = list(product(alphas, learning_rates, layer_sizes))
params_num = len(params_space)
cur_param = 0

# %%
for space_i, space in enumerate(params_space):
    start = time.time()
    mlp = MLPRegressor(alpha = space[0], learning_rate_init = space[1], hidden_layer_sizes = space[2], warm_start = True)
    train_error = []
    cv_error = []
    test_error = []
    
    times = 0
    for i in range(max_iter):
        mlp.partial_fit(X_train_std, y_train)
        train_loss = mean_squared_error(mlp.predict(X_train_std), y_train)
        
        if i>0:
            if (train_error[-1] - train_loss)<0.0001:
                times  = times + 1
                if times >=5:
                    sys.stdout.flush()
                    print(f'Espaço de Parâmetros {space_i}: {space} - Treinamento encerrado por evolução aceitável: {i} iterações | erro={round(train_loss,3)}!')
                    break
            else:
                times = 0
        
        train_error.append(train_loss)
        cv_error.append(mean_squared_error(mlp.predict(X_cv_std), y_cv))
        test_error.append(mean_squared_error(mlp.predict(X_test_std), y_test))
        
        print(f'Espaço de Parâmetros {space_i} {space} - Iterações realizadas: {i} - Train_loss: {train_loss}', end='\r')
        
        if i==max_iter-1:
            sys.stdout.flush()
            print(f'Espaço de Parâmetros {space_i}: {space} - Treinamento encerrado por máximo de iterações: {max_iter}!')
    
    end = time.time()
    
    
    this_dict = {"Espaço":[], "Layers":[], "Train_loss_array":[], "CV_loss_array":[], "Test_loss_array":[]}
    this_dict["Index"] = space_i
    this_dict["Espaço"].append(space)
    this_dict["Alpha"] = space[0]
    this_dict["Learning Rate"] = space[1]
    this_dict["Layers"].append(space[2])
    this_dict["Train_loss_array"].append(train_error)
    this_dict["Train_loss"] = float(train_error[-1])
    this_dict["CV_loss_array"].append(cv_error)
    this_dict["CV_loss"] = float(cv_error[-1])
    this_dict["Test_loss_array"].append(test_error)
    this_dict["Test_loss"] = float(test_error[-1])
    this_dict["num_iter"] = i
    this_dict["time_elapsed"] = (end-start)/60
    
    
    results_df = pd.concat([results_df, pd.DataFrame(this_dict)])
# Out:
# Espaço de Parâmetros 0: (0.001, 0.001, (3,)) - Treinamento encerrado por máximo de iterações: 4000!048754
# Espaço de Parâmetros 1: (0.001, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 1128 iterações | erro=1067.497!
# Espaço de Parâmetros 2: (0.001, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1288 iterações | erro=985.885!
# Espaço de Parâmetros 3: (0.001, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 2003 iterações | erro=894.781!
# Espaço de Parâmetros 4: (0.001, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 1505 iterações | erro=905.975!
# Espaço de Parâmetros 5: (0.001, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 3948 iterações | erro=827.261!
# Espaço de Parâmetros 6: (0.001, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 939 iterações | erro=937.88!
# Espaço de Parâmetros 7: (0.001, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 1569 iterações | erro=815.054!
# Espaço de Parâmetros 8: (0.001, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 2678 iterações | erro=1004.32!
# Espaço de Parâmetros 9: (0.001, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 473 iterações | erro=981.065!
# Espaço de Parâmetros 10: (0.001, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 2196 iterações | erro=902.565!
# Espaço de Parâmetros 11: (0.001, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 171 iterações | erro=984.834!
# Espaço de Parâmetros 12: (0.001, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 1721 iterações | erro=857.659!
# Espaço de Parâmetros 13: (0.001, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 920 iterações | erro=817.872!
# Espaço de Parâmetros 14: (0.001, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 1780 iterações | erro=817.326!
# Espaço de Parâmetros 15: (0.001, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 341 iterações | erro=873.136!
# Espaço de Parâmetros 16: (0.001, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 431 iterações | erro=1005.048!
# Espaço de Parâmetros 17: (0.001, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 145 iterações | erro=991.355!
# Espaço de Parâmetros 18: (0.001, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 543 iterações | erro=1000.526!
# Espaço de Parâmetros 19: (0.001, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 501 iterações | erro=885.65!
# Espaço de Parâmetros 20: (0.001, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 1127 iterações | erro=839.213!
# Espaço de Parâmetros 21: (0.001, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 601 iterações | erro=860.505!
# Espaço de Parâmetros 22: (0.001, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 975 iterações | erro=804.028!
# Espaço de Parâmetros 23: (0.001, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 128 iterações | erro=891.492!
# Espaço de Parâmetros 24: (0.001, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 725 iterações | erro=963.508!
# Espaço de Parâmetros 25: (0.001, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 501 iterações | erro=962.81!
# Espaço de Parâmetros 26: (0.001, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 890 iterações | erro=917.475!
# Espaço de Parâmetros 27: (0.001, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 321 iterações | erro=913.485!
# Espaço de Parâmetros 28: (0.001, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 735 iterações | erro=855.69!
# Espaço de Parâmetros 29: (0.001, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 168 iterações | erro=961.814!
# Espaço de Parâmetros 30: (0.001, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 1209 iterações | erro=829.749!
# Espaço de Parâmetros 31: (0.001, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 448 iterações | erro=905.329!
# Espaço de Parâmetros 32: (0.001, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 328 iterações | erro=974.373!
# Espaço de Parâmetros 33: (0.001, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 87 iterações | erro=1051.602!
# Espaço de Parâmetros 34: (0.001, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 145 iterações | erro=1026.163!
# Espaço de Parâmetros 35: (0.001, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 101 iterações | erro=1145.463!
# Espaço de Parâmetros 36: (0.001, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 222 iterações | erro=950.939!
# Espaço de Parâmetros 37: (0.001, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 84 iterações | erro=1418.696!
# Espaço de Parâmetros 38: (0.001, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 58 iterações | erro=950.406!
# Espaço de Parâmetros 39: (0.001, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 97 iterações | erro=1132.537!
# Espaço de Parâmetros 40: (0.001, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 503 iterações | erro=1007.777!
# Espaço de Parâmetros 41: (0.001, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 132 iterações | erro=1070.268!
# Espaço de Parâmetros 42: (0.001, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 1329 iterações | erro=1117.496!
# Espaço de Parâmetros 43: (0.001, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 422 iterações | erro=1080.217!
# Espaço de Parâmetros 44: (0.001, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 269 iterações | erro=950.119!
# Espaço de Parâmetros 45: (0.001, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 722 iterações | erro=1494.334!
# Espaço de Parâmetros 46: (0.001, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 259 iterações | erro=871.764!
# Espaço de Parâmetros 47: (0.001, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 482 iterações | erro=1197.206!
# Espaço de Parâmetros 48: (0.003, 0.001, (3,)) - Treinamento encerrado por máximo de iterações: 4000!113876
# Espaço de Parâmetros 49: (0.003, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 1293 iterações | erro=1026.094!
# Espaço de Parâmetros 50: (0.003, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1099 iterações | erro=987.166!
# Espaço de Parâmetros 51: (0.003, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 1699 iterações | erro=947.824!
# Espaço de Parâmetros 52: (0.003, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 2920 iterações | erro=872.969!
# Espaço de Parâmetros 53: (0.003, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 2738 iterações | erro=813.155!
# Espaço de Parâmetros 54: (0.003, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 3110 iterações | erro=839.79!
# Espaço de Parâmetros 55: (0.003, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 1660 iterações | erro=768.029!
# Espaço de Parâmetros 56: (0.003, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 3040 iterações | erro=992.151!
# Espaço de Parâmetros 57: (0.003, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 2044 iterações | erro=1493.669!
# Espaço de Parâmetros 58: (0.003, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 2460 iterações | erro=922.103!
# Espaço de Parâmetros 59: (0.003, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 865 iterações | erro=913.535!
# Espaço de Parâmetros 60: (0.003, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 1588 iterações | erro=838.911!
# Espaço de Parâmetros 61: (0.003, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 546 iterações | erro=876.109!
# Espaço de Parâmetros 62: (0.003, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 2350 iterações | erro=825.209!
# Espaço de Parâmetros 63: (0.003, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 342 iterações | erro=887.549!
# Espaço de Parâmetros 64: (0.003, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 549 iterações | erro=1021.87!
# Espaço de Parâmetros 65: (0.003, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 413 iterações | erro=983.546!
# Espaço de Parâmetros 66: (0.003, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 409 iterações | erro=929.795!
# Espaço de Parâmetros 67: (0.003, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 558 iterações | erro=915.65!
# Espaço de Parâmetros 68: (0.003, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 672 iterações | erro=880.258!
# Espaço de Parâmetros 69: (0.003, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 198 iterações | erro=906.978!
# Espaço de Parâmetros 70: (0.003, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 998 iterações | erro=798.112!
# Espaço de Parâmetros 71: (0.003, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 186 iterações | erro=876.322!
# Espaço de Parâmetros 72: (0.003, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 1002 iterações | erro=968.004!
# Espaço de Parâmetros 73: (0.003, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 269 iterações | erro=1047.678!
# Espaço de Parâmetros 74: (0.003, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 589 iterações | erro=933.275!
# Espaço de Parâmetros 75: (0.003, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 339 iterações | erro=927.967!
# Espaço de Parâmetros 76: (0.003, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 147 iterações | erro=880.023!
# Espaço de Parâmetros 77: (0.003, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 155 iterações | erro=906.189!
# Espaço de Parâmetros 78: (0.003, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 1095 iterações | erro=762.531!
# Espaço de Parâmetros 79: (0.003, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 161 iterações | erro=909.598!
# Espaço de Parâmetros 80: (0.003, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 650 iterações | erro=1002.315!
# Espaço de Parâmetros 81: (0.003, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 1695 iterações | erro=991.073!
# Espaço de Parâmetros 82: (0.003, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 498 iterações | erro=927.248!
# Espaço de Parâmetros 83: (0.003, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 829 iterações | erro=959.028!
# Espaço de Parâmetros 84: (0.003, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 270 iterações | erro=919.108!
# Espaço de Parâmetros 85: (0.003, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 1106 iterações | erro=944.431!
# Espaço de Parâmetros 86: (0.003, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 574 iterações | erro=877.541!
# Espaço de Parâmetros 87: (0.003, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 631 iterações | erro=1007.32!
# Espaço de Parâmetros 88: (0.003, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 68 iterações | erro=1090.991!
# Espaço de Parâmetros 89: (0.003, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 504 iterações | erro=1238.836!
# Espaço de Parâmetros 90: (0.003, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 104 iterações | erro=1214.466!
# Espaço de Parâmetros 91: (0.003, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 1967 iterações | erro=1495.428!
# Espaço de Parâmetros 92: (0.003, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 463 iterações | erro=1054.679!
# Espaço de Parâmetros 93: (0.003, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 792 iterações | erro=1228.237!
# Espaço de Parâmetros 94: (0.003, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 44 iterações | erro=1160.962!
# Espaço de Parâmetros 95: (0.003, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 600 iterações | erro=1231.625!
# Espaço de Parâmetros 96: (0.01, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 2222 iterações | erro=1030.921!
# Espaço de Parâmetros 97: (0.01, 0.001, (3, 3)) - Treinamento encerrado por máximo de iterações: 4000!860536
# Espaço de Parâmetros 98: (0.01, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1227 iterações | erro=1009.892!
# Espaço de Parâmetros 99: (0.01, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 742 iterações | erro=949.816!
# Espaço de Parâmetros 100: (0.01, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 1881 iterações | erro=900.65!
# Espaço de Parâmetros 101: (0.01, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 1063 iterações | erro=899.77!
# Espaço de Parâmetros 102: (0.01, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 2426 iterações | erro=841.436!
# Espaço de Parâmetros 103: (0.01, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 2649 iterações | erro=738.268!
# Espaço de Parâmetros 104: (0.01, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 2506 iterações | erro=995.362!
# Espaço de Parâmetros 105: (0.01, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 1360 iterações | erro=970.366!
# Espaço de Parâmetros 106: (0.01, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 448 iterações | erro=970.446!
# Espaço de Parâmetros 107: (0.01, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 746 iterações | erro=866.936!
# Espaço de Parâmetros 108: (0.01, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 532 iterações | erro=945.323!
# Espaço de Parâmetros 109: (0.01, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 891 iterações | erro=847.209!
# Espaço de Parâmetros 110: (0.01, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 2859 iterações | erro=787.246!
# Espaço de Parâmetros 111: (0.01, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 642 iterações | erro=806.156!
# Espaço de Parâmetros 112: (0.01, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 1004 iterações | erro=946.001!
# Espaço de Parâmetros 113: (0.01, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 579 iterações | erro=928.352!
# Espaço de Parâmetros 114: (0.01, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 1677 iterações | erro=981.369!
# Espaço de Parâmetros 115: (0.01, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 827 iterações | erro=888.677!
# Espaço de Parâmetros 116: (0.01, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 850 iterações | erro=830.73!
# Espaço de Parâmetros 117: (0.01, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 860 iterações | erro=833.789!
# Espaço de Parâmetros 118: (0.01, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 313 iterações | erro=885.712!
# Espaço de Parâmetros 119: (0.01, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 421 iterações | erro=813.458!
# Espaço de Parâmetros 120: (0.01, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 839 iterações | erro=1028.528!
# Espaço de Parâmetros 121: (0.01, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 123 iterações | erro=1007.516!
# Espaço de Parâmetros 122: (0.01, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 1220 iterações | erro=899.618!
# Espaço de Parâmetros 123: (0.01, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 523 iterações | erro=889.039!
# Espaço de Parâmetros 124: (0.01, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 1252 iterações | erro=881.205!
# Espaço de Parâmetros 125: (0.01, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 1302 iterações | erro=790.401!
# Espaço de Parâmetros 126: (0.01, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 537 iterações | erro=886.701!
# Espaço de Parâmetros 127: (0.01, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 582 iterações | erro=822.828!
# Espaço de Parâmetros 128: (0.01, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 237 iterações | erro=978.298!
# Espaço de Parâmetros 129: (0.01, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 864 iterações | erro=1165.474!
# Espaço de Parâmetros 130: (0.01, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 543 iterações | erro=904.094!
# Espaço de Parâmetros 131: (0.01, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 118 iterações | erro=962.577!
# Espaço de Parâmetros 132: (0.01, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 488 iterações | erro=921.815!
# Espaço de Parâmetros 133: (0.01, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 246 iterações | erro=957.192!
# Espaço de Parâmetros 134: (0.01, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 54 iterações | erro=947.041!
# Espaço de Parâmetros 135: (0.01, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 317 iterações | erro=942.379!
# Espaço de Parâmetros 136: (0.01, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 2149 iterações | erro=1043.527!
# Espaço de Parâmetros 137: (0.01, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 99 iterações | erro=1113.442!
# Espaço de Parâmetros 138: (0.01, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 490 iterações | erro=1138.509!
# Espaço de Parâmetros 139: (0.01, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 478 iterações | erro=1263.863!
# Espaço de Parâmetros 140: (0.01, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 123 iterações | erro=1172.93!
# Espaço de Parâmetros 141: (0.01, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 1893 iterações | erro=1496.449!
# Espaço de Parâmetros 142: (0.01, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 110 iterações | erro=1183.972!
# Espaço de Parâmetros 143: (0.01, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 548 iterações | erro=1072.928!
# Espaço de Parâmetros 144: (0.03, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 2389 iterações | erro=1128.331!
# Espaço de Parâmetros 145: (0.03, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 1127 iterações | erro=1000.896!
# Espaço de Parâmetros 146: (0.03, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1733 iterações | erro=969.979!
# Espaço de Parâmetros 147: (0.03, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 2498 iterações | erro=904.509!
# Espaço de Parâmetros 148: (0.03, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 1955 iterações | erro=882.534!
# Espaço de Parâmetros 149: (0.03, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 2120 iterações | erro=841.168!
# Espaço de Parâmetros 150: (0.03, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 2641 iterações | erro=816.135!
# Espaço de Parâmetros 151: (0.03, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 2101 iterações | erro=806.24!
# Espaço de Parâmetros 152: (0.03, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 968 iterações | erro=1025.007!
# Espaço de Parâmetros 153: (0.03, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 558 iterações | erro=1006.806!
# Espaço de Parâmetros 154: (0.03, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 752 iterações | erro=941.586!
# Espaço de Parâmetros 155: (0.03, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 813 iterações | erro=899.275!
# Espaço de Parâmetros 156: (0.03, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 841 iterações | erro=886.06!
# Espaço de Parâmetros 157: (0.03, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 332 iterações | erro=908.497!
# Espaço de Parâmetros 158: (0.03, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 1995 iterações | erro=808.084!
# Espaço de Parâmetros 159: (0.03, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 1342 iterações | erro=756.643!
# Espaço de Parâmetros 160: (0.03, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 663 iterações | erro=1034.925!
# Espaço de Parâmetros 161: (0.03, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 1615 iterações | erro=942.198!
# Espaço de Parâmetros 162: (0.03, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 520 iterações | erro=905.885!
# Espaço de Parâmetros 163: (0.03, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 1052 iterações | erro=858.379!
# Espaço de Parâmetros 164: (0.03, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 238 iterações | erro=920.634!
# Espaço de Parâmetros 165: (0.03, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 336 iterações | erro=831.742!
# Espaço de Parâmetros 166: (0.03, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 846 iterações | erro=796.804!
# Espaço de Parâmetros 167: (0.03, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 457 iterações | erro=753.564!
# Espaço de Parâmetros 168: (0.03, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 643 iterações | erro=1029.151!
# Espaço de Parâmetros 169: (0.03, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 474 iterações | erro=1002.757!
# Espaço de Parâmetros 170: (0.03, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 1180 iterações | erro=914.463!
# Espaço de Parâmetros 171: (0.03, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 993 iterações | erro=891.158!
# Espaço de Parâmetros 172: (0.03, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 298 iterações | erro=897.69!
# Espaço de Parâmetros 173: (0.03, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 534 iterações | erro=810.55!
# Espaço de Parâmetros 174: (0.03, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 290 iterações | erro=879.454!
# Espaço de Parâmetros 175: (0.03, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 562 iterações | erro=781.887!
# Espaço de Parâmetros 176: (0.03, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 688 iterações | erro=970.679!
# Espaço de Parâmetros 177: (0.03, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 213 iterações | erro=1034.561!
# Espaço de Parâmetros 178: (0.03, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 66 iterações | erro=1034.399!
# Espaço de Parâmetros 179: (0.03, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 1558 iterações | erro=896.721!
# Espaço de Parâmetros 180: (0.03, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 809 iterações | erro=889.84!
# Espaço de Parâmetros 181: (0.03, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 565 iterações | erro=875.297!
# Espaço de Parâmetros 182: (0.03, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 449 iterações | erro=853.207!
# Espaço de Parâmetros 183: (0.03, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 286 iterações | erro=905.852!
# Espaço de Parâmetros 184: (0.03, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 827 iterações | erro=1085.093!
# Espaço de Parâmetros 185: (0.03, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 73 iterações | erro=1632.286!
# Espaço de Parâmetros 186: (0.03, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 222 iterações | erro=975.473!
# Espaço de Parâmetros 187: (0.03, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 643 iterações | erro=1345.738!
# Espaço de Parâmetros 188: (0.03, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 730 iterações | erro=1034.988!
# Espaço de Parâmetros 189: (0.03, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 352 iterações | erro=997.815!
# Espaço de Parâmetros 190: (0.03, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 211 iterações | erro=1088.9!
# Espaço de Parâmetros 191: (0.03, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 538 iterações | erro=1315.604!
# Espaço de Parâmetros 192: (0.1, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 1847 iterações | erro=1044.086!
# Espaço de Parâmetros 193: (0.1, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 1160 iterações | erro=1025.621!
# Espaço de Parâmetros 194: (0.1, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 2926 iterações | erro=924.234!
# Espaço de Parâmetros 195: (0.1, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 665 iterações | erro=959.971!
# Espaço de Parâmetros 196: (0.1, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 3567 iterações | erro=850.461!
# Espaço de Parâmetros 197: (0.1, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 508 iterações | erro=937.958!
# Espaço de Parâmetros 198: (0.1, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 2218 iterações | erro=841.27!
# Espaço de Parâmetros 199: (0.1, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 2983 iterações | erro=758.348!
# Espaço de Parâmetros 200: (0.1, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 1442 iterações | erro=959.066!
# Espaço de Parâmetros 201: (0.1, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 3458 iterações | erro=909.212!
# Espaço de Parâmetros 202: (0.1, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 1916 iterações | erro=900.498!
# Espaço de Parâmetros 203: (0.1, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 321 iterações | erro=966.762!
# Espaço de Parâmetros 204: (0.1, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 406 iterações | erro=966.213!
# Espaço de Parâmetros 205: (0.1, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 301 iterações | erro=918.519!
# Espaço de Parâmetros 206: (0.1, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 1637 iterações | erro=840.749!
# Espaço de Parâmetros 207: (0.1, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 1034 iterações | erro=810.723!
# Espaço de Parâmetros 208: (0.1, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 352 iterações | erro=1022.887!
# Espaço de Parâmetros 209: (0.1, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 100 iterações | erro=1104.872!
# Espaço de Parâmetros 210: (0.1, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 670 iterações | erro=1493.704!
# Espaço de Parâmetros 211: (0.1, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 361 iterações | erro=927.492!
# Espaço de Parâmetros 212: (0.1, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 451 iterações | erro=882.545!
# Espaço de Parâmetros 213: (0.1, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 425 iterações | erro=830.988!
# Espaço de Parâmetros 214: (0.1, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 373 iterações | erro=845.786!
# Espaço de Parâmetros 215: (0.1, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 70 iterações | erro=918.707!
# Espaço de Parâmetros 216: (0.1, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 381 iterações | erro=941.305!
# Espaço de Parâmetros 217: (0.1, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 1457 iterações | erro=932.727!
# Espaço de Parâmetros 218: (0.1, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 373 iterações | erro=904.197!
# Espaço de Parâmetros 219: (0.1, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 148 iterações | erro=914.625!
# Espaço de Parâmetros 220: (0.1, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 590 iterações | erro=858.639!
# Espaço de Parâmetros 221: (0.1, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 1061 iterações | erro=793.061!
# Espaço de Parâmetros 222: (0.1, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 286 iterações | erro=854.587!
# Espaço de Parâmetros 223: (0.1, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 497 iterações | erro=813.962!
# Espaço de Parâmetros 224: (0.1, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 438 iterações | erro=1042.453!
# Espaço de Parâmetros 225: (0.1, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 188 iterações | erro=997.863!
# Espaço de Parâmetros 226: (0.1, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 573 iterações | erro=922.728!
# Espaço de Parâmetros 227: (0.1, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 1461 iterações | erro=915.909!
# Espaço de Parâmetros 228: (0.1, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 129 iterações | erro=971.025!
# Espaço de Parâmetros 229: (0.1, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 183 iterações | erro=930.408!
# Espaço de Parâmetros 230: (0.1, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 309 iterações | erro=866.944!
# Espaço de Parâmetros 231: (0.1, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 77 iterações | erro=1055.588!
# Espaço de Parâmetros 232: (0.1, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 320 iterações | erro=1044.628!
# Espaço de Parâmetros 233: (0.1, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 509 iterações | erro=1494.359!
# Espaço de Parâmetros 234: (0.1, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 373 iterações | erro=1414.561!
# Espaço de Parâmetros 235: (0.1, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 230 iterações | erro=1359.794!
# Espaço de Parâmetros 236: (0.1, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 402 iterações | erro=1069.919!
# Espaço de Parâmetros 237: (0.1, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 131 iterações | erro=1177.359!
# Espaço de Parâmetros 238: (0.1, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 962 iterações | erro=1001.313!
# Espaço de Parâmetros 239: (0.1, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 340 iterações | erro=1494.491!
# Espaço de Parâmetros 240: (0.3, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 2492 iterações | erro=1125.198!
# Espaço de Parâmetros 241: (0.3, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 800 iterações | erro=1030.837!
# Espaço de Parâmetros 242: (0.3, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 2025 iterações | erro=962.749!
# Espaço de Parâmetros 243: (0.3, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 2271 iterações | erro=887.992!
# Espaço de Parâmetros 244: (0.3, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 3273 iterações | erro=864.056!
# Espaço de Parâmetros 245: (0.3, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 2824 iterações | erro=806.211!
# Espaço de Parâmetros 246: (0.3, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 1663 iterações | erro=880.809!
# Espaço de Parâmetros 247: (0.3, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 400 iterações | erro=930.558!
# Espaço de Parâmetros 248: (0.3, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 2736 iterações | erro=1007.959!
# Espaço de Parâmetros 249: (0.3, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 653 iterações | erro=1026.87!
# Espaço de Parâmetros 250: (0.3, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 707 iterações | erro=954.792!
# Espaço de Parâmetros 251: (0.3, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 400 iterações | erro=929.899!
# Espaço de Parâmetros 252: (0.3, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 767 iterações | erro=891.361!
# Espaço de Parâmetros 253: (0.3, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 656 iterações | erro=849.41!
# Espaço de Parâmetros 254: (0.3, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 1496 iterações | erro=793.173!
# Espaço de Parâmetros 255: (0.3, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 1294 iterações | erro=723.757!
# Espaço de Parâmetros 256: (0.3, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 489 iterações | erro=1002.504!
# Espaço de Parâmetros 257: (0.3, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 349 iterações | erro=999.077!
# Espaço de Parâmetros 258: (0.3, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 217 iterações | erro=1048.099!
# Espaço de Parâmetros 259: (0.3, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 443 iterações | erro=906.612!
# Espaço de Parâmetros 260: (0.3, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 441 iterações | erro=869.827!
# Espaço de Parâmetros 261: (0.3, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 699 iterações | erro=823.666!
# Espaço de Parâmetros 262: (0.3, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 868 iterações | erro=822.967!
# Espaço de Parâmetros 263: (0.3, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 489 iterações | erro=796.031!
# Espaço de Parâmetros 264: (0.3, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 441 iterações | erro=982.643!
# Espaço de Parâmetros 265: (0.3, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 432 iterações | erro=995.709!
# Espaço de Parâmetros 266: (0.3, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 283 iterações | erro=979.585!
# Espaço de Parâmetros 267: (0.3, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 82 iterações | erro=953.7!
# Espaço de Parâmetros 268: (0.3, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 1429 iterações | erro=819.709!
# Espaço de Parâmetros 269: (0.3, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 327 iterações | erro=885.073!
# Espaço de Parâmetros 270: (0.3, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 84 iterações | erro=983.151!
# Espaço de Parâmetros 271: (0.3, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 330 iterações | erro=868.462!
# Espaço de Parâmetros 272: (0.3, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 504 iterações | erro=975.276!
# Espaço de Parâmetros 273: (0.3, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 650 iterações | erro=909.634!
# Espaço de Parâmetros 274: (0.3, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 43 iterações | erro=1007.7!
# Espaço de Parâmetros 275: (0.3, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 448 iterações | erro=1134.166!
# Espaço de Parâmetros 276: (0.3, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 199 iterações | erro=1081.894!
# Espaço de Parâmetros 277: (0.3, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 71 iterações | erro=1140.142!
# Espaço de Parâmetros 278: (0.3, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 82 iterações | erro=976.688!
# Espaço de Parâmetros 279: (0.3, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 206 iterações | erro=981.681!
# Espaço de Parâmetros 280: (0.3, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 290 iterações | erro=1164.039!
# Espaço de Parâmetros 281: (0.3, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 525 iterações | erro=2219.692!
# Espaço de Parâmetros 282: (0.3, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 129 iterações | erro=1065.723!
# Espaço de Parâmetros 283: (0.3, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 521 iterações | erro=1031.632!
# Espaço de Parâmetros 284: (0.3, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 181 iterações | erro=1273.155!
# Espaço de Parâmetros 285: (0.3, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 502 iterações | erro=1177.351!
# Espaço de Parâmetros 286: (0.3, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 231 iterações | erro=1027.84!
# Espaço de Parâmetros 287: (0.3, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 1802 iterações | erro=1289.569!
# Espaço de Parâmetros 288: (1, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 1415 iterações | erro=1043.259!
# Espaço de Parâmetros 289: (1, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 1921 iterações | erro=1021.296!
# Espaço de Parâmetros 290: (1, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1935 iterações | erro=955.798!
# Espaço de Parâmetros 291: (1, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 1467 iterações | erro=910.659!
# Espaço de Parâmetros 292: (1, 0.001, (7,)) - Treinamento encerrado por máximo de iterações: 4000!30397
# Espaço de Parâmetros 293: (1, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 616 iterações | erro=922.879!
# Espaço de Parâmetros 294: (1, 0.001, (9,)) - Treinamento encerrado por máximo de iterações: 4000!06881
# Espaço de Parâmetros 295: (1, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 1762 iterações | erro=784.375!
# Espaço de Parâmetros 296: (1, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 2187 iterações | erro=1008.447!
# Espaço de Parâmetros 297: (1, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 3376 iterações | erro=913.175!
# Espaço de Parâmetros 298: (1, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 631 iterações | erro=966.982!
# Espaço de Parâmetros 299: (1, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 379 iterações | erro=952.907!
# Espaço de Parâmetros 300: (1, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 642 iterações | erro=885.938!
# Espaço de Parâmetros 301: (1, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 1621 iterações | erro=793.603!
# Espaço de Parâmetros 302: (1, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 2191 iterações | erro=790.461!
# Espaço de Parâmetros 303: (1, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 2411 iterações | erro=712.914!
# Espaço de Parâmetros 304: (1, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 2048 iterações | erro=946.656!
# Espaço de Parâmetros 305: (1, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 616 iterações | erro=945.582!
# Espaço de Parâmetros 306: (1, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 348 iterações | erro=938.755!
# Espaço de Parâmetros 307: (1, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 92 iterações | erro=970.071!
# Espaço de Parâmetros 308: (1, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 2135 iterações | erro=858.646!
# Espaço de Parâmetros 309: (1, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 372 iterações | erro=882.314!
# Espaço de Parâmetros 310: (1, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 829 iterações | erro=872.271!
# Espaço de Parâmetros 311: (1, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 265 iterações | erro=827.62!
# Espaço de Parâmetros 312: (1, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 1317 iterações | erro=951.292!
# Espaço de Parâmetros 313: (1, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 133 iterações | erro=1014.755!
# Espaço de Parâmetros 314: (1, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 315 iterações | erro=973.117!
# Espaço de Parâmetros 315: (1, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 1140 iterações | erro=843.772!
# Espaço de Parâmetros 316: (1, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 90 iterações | erro=917.331!
# Espaço de Parâmetros 317: (1, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 1370 iterações | erro=777.6!
# Espaço de Parâmetros 318: (1, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 913 iterações | erro=861.393!
# Espaço de Parâmetros 319: (1, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 624 iterações | erro=852.091!
# Espaço de Parâmetros 320: (1, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 52 iterações | erro=1146.236!
# Espaço de Parâmetros 321: (1, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 305 iterações | erro=981.057!
# Espaço de Parâmetros 322: (1, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 1192 iterações | erro=938.437!
# Espaço de Parâmetros 323: (1, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 573 iterações | erro=940.513!
# Espaço de Parâmetros 324: (1, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 101 iterações | erro=1141.696!
# Espaço de Parâmetros 325: (1, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 89 iterações | erro=1111.604!
# Espaço de Parâmetros 326: (1, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 444 iterações | erro=942.22!
# Espaço de Parâmetros 327: (1, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 442 iterações | erro=985.378!
# Espaço de Parâmetros 328: (1, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 394 iterações | erro=1168.391!
# Espaço de Parâmetros 329: (1, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 290 iterações | erro=1120.746!
# Espaço de Parâmetros 330: (1, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 2412 iterações | erro=1048.457!
# Espaço de Parâmetros 331: (1, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 1261 iterações | erro=1216.826!
# Espaço de Parâmetros 332: (1, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 395 iterações | erro=1087.343!
# Espaço de Parâmetros 333: (1, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 1111 iterações | erro=1410.668!
# Espaço de Parâmetros 334: (1, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 63 iterações | erro=1292.213!
# Espaço de Parâmetros 335: (1, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 807 iterações | erro=1407.162!
# Espaço de Parâmetros 336: (3, 0.001, (3,)) - Treinamento encerrado por evolução aceitável: 996 iterações | erro=1064.028!
# Espaço de Parâmetros 337: (3, 0.001, (3, 3)) - Treinamento encerrado por evolução aceitável: 2780 iterações | erro=935.143!
# Espaço de Parâmetros 338: (3, 0.001, (5,)) - Treinamento encerrado por evolução aceitável: 1684 iterações | erro=947.574!
# Espaço de Parâmetros 339: (3, 0.001, (5, 5)) - Treinamento encerrado por evolução aceitável: 2036 iterações | erro=907.381!
# Espaço de Parâmetros 340: (3, 0.001, (7,)) - Treinamento encerrado por evolução aceitável: 1962 iterações | erro=882.309!
# Espaço de Parâmetros 341: (3, 0.001, (7, 7)) - Treinamento encerrado por evolução aceitável: 3586 iterações | erro=794.131!
# Espaço de Parâmetros 342: (3, 0.001, (9,)) - Treinamento encerrado por evolução aceitável: 1746 iterações | erro=864.509!
# Espaço de Parâmetros 343: (3, 0.001, (9, 9)) - Treinamento encerrado por evolução aceitável: 1521 iterações | erro=810.421!
# Espaço de Parâmetros 344: (3, 0.003, (3,)) - Treinamento encerrado por evolução aceitável: 893 iterações | erro=1033.598!
# Espaço de Parâmetros 345: (3, 0.003, (3, 3)) - Treinamento encerrado por evolução aceitável: 2264 iterações | erro=940.888!
# Espaço de Parâmetros 346: (3, 0.003, (5,)) - Treinamento encerrado por evolução aceitável: 2858 iterações | erro=891.503!
# Espaço de Parâmetros 347: (3, 0.003, (5, 5)) - Treinamento encerrado por evolução aceitável: 1669 iterações | erro=857.351!
# Espaço de Parâmetros 348: (3, 0.003, (7,)) - Treinamento encerrado por evolução aceitável: 1120 iterações | erro=871.507!
# Espaço de Parâmetros 349: (3, 0.003, (7, 7)) - Treinamento encerrado por evolução aceitável: 1083 iterações | erro=830.596!
# Espaço de Parâmetros 350: (3, 0.003, (9,)) - Treinamento encerrado por evolução aceitável: 1609 iterações | erro=819.985!
# Espaço de Parâmetros 351: (3, 0.003, (9, 9)) - Treinamento encerrado por evolução aceitável: 972 iterações | erro=769.71!
# Espaço de Parâmetros 352: (3, 0.01, (3,)) - Treinamento encerrado por evolução aceitável: 86 iterações | erro=1109.781!
# Espaço de Parâmetros 353: (3, 0.01, (3, 3)) - Treinamento encerrado por evolução aceitável: 1259 iterações | erro=983.67!
# Espaço de Parâmetros 354: (3, 0.01, (5,)) - Treinamento encerrado por evolução aceitável: 1190 iterações | erro=932.361!
# Espaço de Parâmetros 355: (3, 0.01, (5, 5)) - Treinamento encerrado por evolução aceitável: 887 iterações | erro=858.496!
# Espaço de Parâmetros 356: (3, 0.01, (7,)) - Treinamento encerrado por evolução aceitável: 466 iterações | erro=874.196!
# Espaço de Parâmetros 357: (3, 0.01, (7, 7)) - Treinamento encerrado por evolução aceitável: 202 iterações | erro=942.556!
# Espaço de Parâmetros 358: (3, 0.01, (9,)) - Treinamento encerrado por evolução aceitável: 171 iterações | erro=876.118!
# Espaço de Parâmetros 359: (3, 0.01, (9, 9)) - Treinamento encerrado por evolução aceitável: 267 iterações | erro=839.629!
# Espaço de Parâmetros 360: (3, 0.03, (3,)) - Treinamento encerrado por evolução aceitável: 402 iterações | erro=1079.227!
# Espaço de Parâmetros 361: (3, 0.03, (3, 3)) - Treinamento encerrado por evolução aceitável: 811 iterações | erro=968.337!
# Espaço de Parâmetros 362: (3, 0.03, (5,)) - Treinamento encerrado por evolução aceitável: 257 iterações | erro=923.743!
# Espaço de Parâmetros 363: (3, 0.03, (5, 5)) - Treinamento encerrado por evolução aceitável: 923 iterações | erro=892.639!
# Espaço de Parâmetros 364: (3, 0.03, (7,)) - Treinamento encerrado por evolução aceitável: 499 iterações | erro=905.87!
# Espaço de Parâmetros 365: (3, 0.03, (7, 7)) - Treinamento encerrado por evolução aceitável: 830 iterações | erro=836.225!
# Espaço de Parâmetros 366: (3, 0.03, (9,)) - Treinamento encerrado por evolução aceitável: 165 iterações | erro=909.375!
# Espaço de Parâmetros 367: (3, 0.03, (9, 9)) - Treinamento encerrado por evolução aceitável: 741 iterações | erro=860.898!
# Espaço de Parâmetros 368: (3, 0.1, (3,)) - Treinamento encerrado por evolução aceitável: 1047 iterações | erro=974.409!
# Espaço de Parâmetros 369: (3, 0.1, (3, 3)) - Treinamento encerrado por evolução aceitável: 216 iterações | erro=1066.164!
# Espaço de Parâmetros 370: (3, 0.1, (5,)) - Treinamento encerrado por evolução aceitável: 752 iterações | erro=981.834!
# Espaço de Parâmetros 371: (3, 0.1, (5, 5)) - Treinamento encerrado por evolução aceitável: 283 iterações | erro=1195.265!
# Espaço de Parâmetros 372: (3, 0.1, (7,)) - Treinamento encerrado por evolução aceitável: 227 iterações | erro=986.778!
# Espaço de Parâmetros 373: (3, 0.1, (7, 7)) - Treinamento encerrado por evolução aceitável: 61 iterações | erro=1213.135!
# Espaço de Parâmetros 374: (3, 0.1, (9,)) - Treinamento encerrado por evolução aceitável: 328 iterações | erro=979.826!
# Espaço de Parâmetros 375: (3, 0.1, (9, 9)) - Treinamento encerrado por evolução aceitável: 211 iterações | erro=1075.663!
# Espaço de Parâmetros 376: (3, 0.3, (3,)) - Treinamento encerrado por evolução aceitável: 67 iterações | erro=1285.394!
# Espaço de Parâmetros 377: (3, 0.3, (3, 3)) - Treinamento encerrado por evolução aceitável: 88 iterações | erro=1194.993!
# Espaço de Parâmetros 378: (3, 0.3, (5,)) - Treinamento encerrado por evolução aceitável: 81 iterações | erro=1196.87!
# Espaço de Parâmetros 379: (3, 0.3, (5, 5)) - Treinamento encerrado por evolução aceitável: 1448 iterações | erro=1356.3!
# Espaço de Parâmetros 380: (3, 0.3, (7,)) - Treinamento encerrado por evolução aceitável: 34 iterações | erro=1290.996!
# Espaço de Parâmetros 381: (3, 0.3, (7, 7)) - Treinamento encerrado por evolução aceitável: 373 iterações | erro=1354.587!
# Espaço de Parâmetros 382: (3, 0.3, (9,)) - Treinamento encerrado por evolução aceitável: 92 iterações | erro=1480.993!
# Espaço de Parâmetros 383: (3, 0.3, (9, 9)) - Treinamento encerrado por evolução aceitável: 60 iterações | erro=1557.77!

# %%
results_df.sort_values(['CV_loss','num_iter'], ascending = [True, False]).to_csv('result_of_384_iterations_v2.csv')

# %%
two = pd.read_csv('result_of_384_iterations_v2.csv')
two.sort_values('CV_loss')
# Out:
#      Unnamed: 0                 Espaço  \
# 0             0     (3, 0.001, (5, 5))
# 1             0        (3, 0.01, (9,))
# 2             0        (3, 0.03, (5,))
# 3             0     (0.3, 0.001, (7,))
# 4             0    (0.03, 0.001, (7,))
# ..          ...                    ...
# 379           0    (0.01, 0.3, (7, 7))
# 380           0    (0.03, 0.3, (3, 3))
# 381           0   (0.003, 0.001, (3,))
# 382           0  (0.01, 0.001, (3, 3))
# 383           0   (0.001, 0.001, (3,))
#
#                                       Train_loss_array   Train_loss  \
# 0    [14493.36001562765, 14355.94724030256, 14189.6...   900.500857
# 1    [13184.929949868536, 10579.235376625304, 7022....   874.372596
# 2    [9761.610953266552, 3482.4960460940792, 2602.8...   907.457619
# 3    [14404.023668797556, 14249.969935514022, 14083...   863.459598
# 4    [14729.488417773136, 14635.47226236495, 14531....   880.753405
# ..                                                 ...          ...
# 379  [3382.333941948181, 1459.4021032332942, 1396.4...  1494.543568
# 380  [2695.9050601175436, 1638.170841708318, 1304.1...  1522.017452
# 381  [14863.07651957341, 14827.793079191844, 14799....  1797.778318
# 382  [14951.192899312013, 14914.50583325654, 14888....  1818.797469
# 383  [15164.802135616277, 15116.351025151534, 15077...  1831.005680
#
#                                          CV_loss_array      CV_loss  \
# 0    [14324.928527878817, 14185.300545980257, 14016...   852.745965
# 1    [13014.215618674489, 10369.97309584292, 6760.3...   857.319158
# 2    [9620.452316460773, 3250.450813320254, 2323.38...   859.541649
# 3    [14243.777221416092, 14087.695920043316, 13917...   868.603314
# 4    [14561.071457850574, 14468.619675097449, 14365...   868.753139
# ..                                                 ...          ...
# 379  [3179.4234054300464, 1330.9579217766552, 1311....  1348.996406
# 380  [2386.18822126597, 1536.2510327219625, 1183.83...  1486.254038
# 381  [14701.92126124886, 14667.335205845755, 14639....  1650.251872
# 382  [14787.545303483945, 14753.832800833683, 14730...  1671.207188
# 383  [15008.035117638929, 14959.73322077658, 14920....  1683.379269
#
#                                        Test_loss_array    Test_loss  num_iter  \
# 0    [14049.326624460738, 13911.957559550694, 13746...   997.442523    2036.0
# 1    [12761.678170288875, 10185.850550834595, 6713....   936.537712     171.0
# 2    [9395.243304577563, 3291.5386897315316, 2497.9...   987.245765     257.0
# 3    [13971.089621879732, 13820.002430171937, 13657...   968.341099    3273.0
# 4    [14291.81651856337, 14200.420444297371, 14099....   964.147024    1955.0
# ..                                                 ...          ...       ...
# 379  [3420.6640703144967, 1472.138966054581, 1437.7...  1367.378788    1893.0
# 380  [2613.4796927980133, 1657.1011134757605, 1258....  1506.218480      73.0
# 381  [14415.669228562347, 14380.60516132402, 14352....  1620.537069    3999.0
# 382  [14502.846462681997, 14468.596608096146, 14443...  1639.941193    3999.0
# 383  [14710.927547979823, 14664.48298828424, 14627....  1651.235290    3999.0
#
#      time_elapsed  Layers  Index  Alpha  Learning Rate
# 0        0.654762  (5, 5)  339.0  3.000          0.001
# 1        0.043960    (9,)  358.0  3.000          0.010
# 2        0.062776    (5,)  362.0  3.000          0.030
# 3        0.917592    (7,)  244.0  0.300          0.001
# 4        0.824552    (7,)  148.0  0.030          0.001
# ..            ...     ...    ...    ...            ...
# 379      0.854137  (7, 7)  141.0  0.010          0.300
# 380      0.029566  (3, 3)  185.0  0.030          0.300
# 381      1.066623    (3,)   48.0  0.003          0.001
# 382      1.629449  (3, 3)   97.0  0.010          0.001
# 383      1.010710    (3,)    0.0  0.001          0.001
#
# [384 rows x 14 columns]

# %%
alpha = two.groupby('Alpha')['CV_loss'].agg([np.mean, np.min, np.max])
alpha['score'] = (alpha['mean']+alpha['amin'])/2
print('Alpha')
print(alpha.sort_values('score').iloc[0])
print(alpha.sort_values('mean').iloc[0])
print(alpha.sort_values('amin').iloc[0])
print()
print('Layers')
layers = two.groupby('Layers')['CV_loss'].agg([np.mean, np.min, np.max])
layers['score'] = (layers['mean']+layers['amin'])/2
print(layers.sort_values('score').iloc[0])
print(layers.sort_values('mean').iloc[0])
print(layers.sort_values('amin').iloc[0])
print()
print('Learning Rate')
learning_rate = two.groupby('Learning Rate')['CV_loss'].agg([np.mean, np.min, np.max])
learning_rate['score'] = (learning_rate['mean']+learning_rate['amin'])/2
print(learning_rate.sort_values('score').iloc[0])
print(learning_rate.sort_values('mean').iloc[0])
print(learning_rate.sort_values('amin').iloc[0])
# Out:
# Alpha
# mean      946.913200
# amin      852.745965
# amax     1197.234465
# score     899.829583
# Name: 3.0, dtype: float64
# mean      946.913200
# amin      852.745965
# amax     1197.234465
# score     899.829583
# Name: 3.0, dtype: float64
# mean      946.913200
# amin      852.745965
# amax     1197.234465
# score     899.829583
# Name: 3.0, dtype: float64
#
# Layers
# mean      941.058219
# amin      857.319158
# amax     1108.197801
# score     899.188688
# Name: (9,), dtype: float64
# mean      939.400596
# amin      868.603314
# amax     1150.556112
# score     904.001955
# Name: (7,), dtype: float64
# mean      958.637856
# amin      852.745965
# amax     1348.708419
# score     905.691910
# Name: (5, 5), dtype: float64
#
# Learning Rate
# mean      930.955088
# amin      859.541649
# amax     1073.322944
# score     895.248368
# Name: 0.03, dtype: float64
# mean      930.955088
# amin      859.541649
# amax     1073.322944
# score     895.248368
# Name: 0.03, dtype: float64
# mean      961.307184
# amin      852.745965
# amax     1683.379269
# score     907.026574
# Name: 0.001, dtype: float64

# %%
test_df = main_df.loc[main_df['database']!= 'extended_ballroom']
test_df['database'].unique()

# %%
test_df = main_df.loc[main_df['database']!= 'extended_ballroom']

X = test_df.iloc[:, :66]
y = test_df.iloc[:, [66]]
X_train, X_test, y_train, y_test = train_test_split(X, y)

y_train = y_train.values.reshape(-1,)
y_test = y_test.values.reshape(-1,)

plt.subplot(2,1,1)
plt.hist(y_train, bins = 273)
plt.subplot(2,1,2)
plt.hist(y_test, bins = 273)
plt.show()

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha = 0.4, normalize=True)
lasso.fit(X,y)
print(lasso.coef_)

plt.plot(lasso.coef_, range(len(X.columns)))
plt.yticks(range(len(X.columns)), X.columns, rotation = -15)
plt.show()




#import seaborn as sns
#sns.heatmap(main_df.corr(), square=True, cmap='RdYlGn')

main_df.corr().loc[:, ['bpm']].iloc[:-1].describe()

# %%
mlp = MLPRegressor(max_iter=2000)

norm = StandardScaler()
quantile = QuantileTransformer()

mse = make_scorer(mean_squared_error, greater_is_better=False)
mae = make_scorer(mean_absolute_error,  greater_is_better=False)
r2 = make_scorer(r2_score)

param_grid_mlp = {'model__hidden_layer_sizes': [(5,), (5,5)],
                  'model__learning_rate_init': [0.01, 0.03, 0.1],
                  'model__alpha': [0.003, 0.01, 0.03, 0.1]}


#MLP com Standard Scaler
mlp_scale_pipe= Pipeline([
    ('scale', norm),
    ('model', mlp)
])

mlp_scale = GridSearchCV(estimator = mlp_scale_pipe,
                   param_grid = param_grid_mlp,
                   scoring = {'mse': mse, 'mae': mae, 'r2': r2},
                   refit='r2',
                   cv=10,
                   n_jobs=-1)



#MLP com Quantile Transform
mlp_quant_pipe = Pipeline([
    ('scale', quantile),
    ('model', mlp)
])

mlp_quant = GridSearchCV(estimator = mlp_quant_pipe,
                   param_grid = param_grid_mlp,
                   scoring = {'mse': mse, 'mae': mae, 'r2': r2},
                   refit='r2',
                   cv=10,
                   n_jobs=-1)

# %%
start = time.time()
mlp_scale.fit(X_train, y_train)
end = time.time()

print(f'MLP com Standard Scaler Treinado em {(end-start)/60} minutos')
print()

# %%
start = time.time()
mlp_quant.fit(X_train, y_train)
end = time.time()

print(f'MLP com Quantile Transformer Treinado em {(end-start)/60} minutos')
print()

# %%
print(mlp_scale.best_score_)
print(mlp_scale.best_params_)
print()

print(mlp_quant.best_score_)
print(mlp_quant.best_params_)

# %%
pd.DataFrame(mlp_scale.cv_results_).loc[:,['mean_test_mse', 'rank_test_mse', 'mean_test_mae', 'rank_test_mae', 'mean_test_r2', 'rank_test_r2']]

# %%
X_train_std = StandardScaler().fit_transform(X_train)
X_test_std = StandardScaler().fit_transform(X_test)

# %%
X_train_poly = PolynomialFeatures(2).fit_transform(X_train)
X_test_poly = PolynomialFeatures(2).fit_transform(X_test)

# %%
train = []
test = []

mlp_alone = MLPRegressor(max_iter = 1000, alpha = 0.3, hidden_layer_sizes = (5,), learning_rate_init = 0.001, warm_start = True)

times = 0

for i in range(5500):
    mlp_alone.partial_fit(X_train_std, y_train)
    train_loss = mean_squared_error(mlp_alone.predict(X_train_std), y_train)
    
    evolution = 0
    if i>0:    
        evolution = train[-1]-train_loss
        if np.abs(evolution) < 0.001:
            times = times + 1
            if times > 10:
                sys.stdout.flush()
                print(f'Treinamento encerrado por evolução aceitável: {evolution} com {i} iterações!')
                break
            else:
                times = 0
            
            
    train.append(train_loss)
    pred = mlp_alone.predict(X_test_std)
    test_loss  = mean_squared_error(pred, y_test)
    test.append(test_loss) 
    print(f'Iterações realizadas: {i} ---- Evolução: {evolution}', end='\r')
    
if i==1199:
    print('Treinamento encerrado por máximo de iterações!')
    i=i+1

# %%
plt.plot(range(i+1), test, label='teste')
plt.plot(range(i+1), train, label='train')
plt.legend()
plt.show()

# %%
mean_squared_error(mlp_alone.predict(X_test_std), y_test)

# %%
bancos = {}
bancos_names = main_df['database'].unique()

for banco in bancos_names:
    banco_i = main_df.loc[main_df['database']==banco]
    bancos[banco] = banco_i.iloc[:, :67]

# %%
bancos_names

# %%
plt.hist(bancos['banco1']['bpm'], bins = 150);
plt.show()

# %%
for banco in bancos:
